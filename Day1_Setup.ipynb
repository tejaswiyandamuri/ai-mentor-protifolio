# %% [markdown]
# <a href="https://colab.research.google.com/github/tejaswiyandamuri/ai-mentor-protifolio/blob/main/Day1_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os, getpass
from groq import Groq

os.environ['GROQ_API_KEY'] = getpass.getpass('Paste your Groq API key: ')

client = Groq(api_key=os.environ['GROQ_API_KEY'])

response = client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=[
        {
            "role": "user",
            "content": "Explain the 5-Layer AI Skill Pyramid in 4 short bullet points."
        }
    ]
)

print(response.choices[0].message.content)
# Out:
# Paste your Groq API key: ··········
# The 5-Layer AI Skill Pyramid is a framework for understanding the progression of skills required to work with artificial intelligence. Here are 4 key points about the pyramid in brief:
# * The base of the pyramid consists of **Foundational Skills**, including basic programming and data analysis.
# * The next layers build upon this foundation, with **Business Acumen**, **Technical Skills**, and **Specialized Skills** in areas like machine learning and deep learning.
# * As you move up the pyramid, the skills become more advanced and specialized, requiring a deeper understanding of AI concepts and technologies.
# * The top of the pyramid represents **Strategic Skills**, where professionals can apply AI to drive business innovation, make strategic decisions, and lead organizational transformation.

# %%
import os, getpass
os.environ['GEMINI_API_KEY'] = getpass.getpass('Paste your Google AI Studio key: ')
# Out:
# Paste your Google AI Studio key: ··········

# %%
# !pip install -q groq
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.7/143.7 kB 8.3 MB/s eta 0:00:00
